# %%
import numpy as np
import jax
import jax.numpy as jnp
import optax
import pulp
import importlib
from sklearn.covariance import graphical_lasso as skl_graphical_lasso
import matplotlib.pyplot as plt

import GGM_sampler
import GGM_inference
import GGM_diagnostics

# %%
importlib.reload(GGM_inference)
importlib.reload(GGM_diagnostics)
importlib.reload(GGM_sampler)
# Out:
# <module 'GGM_sampler' from '/Users/lucaraffo/Desktop/final/GGM_sampler.py'>

# %%
n_spins = 10
n_samples = 100

precision = GGM_sampler.precision_maker(n_spins, p = 0.1)

samples = GGM_sampler.precision_sampler(precision, n_samples)

# %%
precision_hat_mle = GGM_inference.naive_mle(samples)

# %%
precision_hat_gl = GGM_inference.graphical_lasso(samples)

# %%
precision_hat_sm = GGM_inference.graphical_score_matching(samples)

# %%
precision_hat_cm = GGM_inference.clime(samples)

# %%
plt.imshow(precision, cmap="viridis", interpolation="nearest", vmin=-1.0, vmax=1.5)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
plt.imshow(precision_hat_mle, cmap="viridis", interpolation="nearest", vmin=-1.0, vmax=1.5)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
plt.imshow(precision_hat_gl, cmap="viridis", interpolation="nearest", vmin=-1.0, vmax=1.5)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
plt.imshow(precision_hat_sm, cmap="viridis", interpolation="nearest", vmin=-1.0, vmax=1.5)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
plt.imshow(precision_hat_cm, cmap="viridis", interpolation="nearest", vmin=-1.0, vmax=1.5)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
t_n_spins = 30
t_n_samples = 300

t_precision = GGM_sampler.precision_maker(t_n_spins, p = 0.1)

tsamples = GGM_sampler.precision_sampler(t_precision, t_n_samples)

# %%
t_precision_hat_mle = GGM_inference.naive_mle(tsamples)

# %%
t_precision_hat_gl = GGM_inference.graphical_lasso(tsamples)

# %%
t_precision_hat_sm = GGM_inference.graphical_score_matching(tsamples)

# %%
t_precision_hat_cm = GGM_inference.clime(tsamples)

# %%
plt.imshow(t_precision, cmap="viridis", interpolation="nearest", vmin=0.0, vmax=2.0)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
plt.imshow(t_precision_hat_mle, cmap="viridis", interpolation="nearest", vmin=0.0, vmax=2.0)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
plt.imshow(t_precision_hat_gl, cmap="viridis", interpolation="nearest", vmin=0.0, vmax=2.0)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
plt.imshow(t_precision_hat_sm, cmap="viridis", interpolation="nearest", vmin=0.0, vmax=2.0)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()

# %%
plt.imshow(t_precision_hat_cm, cmap="viridis", interpolation="nearest", vmin=0.0, vmax=2.0)
plt.colorbar(label="value")
plt.title("Heatmap")
plt.show()
