# %%
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import importlib
import optax
from sklearn.covariance import graphical_lasso as skl_graphical_lasso

import GGM_sampler
import J_sampler
import GGM_inference
import J_inference
import GGM_diagnostics

# %%
importlib.reload(GGM_inference)
importlib.reload(GGM_diagnostics)
# Out:
# <module 'GGM_diagnostics' from '/Users/lucaraffo/Desktop/final/GGM_diagnostics.py'>

# %%
n_spins = 10
n_samples = 100

precision = GGM_sampler.precision_maker(n_spins, p = 0.1)

samples = GGM_sampler.precision_sampler(precision, n_samples)

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "naive_mle")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_lasso")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_score_matching")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "clime")

# %%
n_spins = 20
n_samples = 200

precision = GGM_sampler.precision_maker(n_spins, p = 0.1)

samples = GGM_sampler.precision_sampler(precision, n_samples)

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "naive_mle")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_lasso")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_score_matching")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "clime")

# %%
n_spins = 50
n_samples = 500

precision = GGM_sampler.precision_maker(n_spins, p = 0.1)

samples = GGM_sampler.precision_sampler(precision, n_samples)

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "naive_mle")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_lasso")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_score_matching")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "clime")

# %%
n_spins = 30
n_samples = 300

precision = GGM_sampler.precision_maker(n_spins, p = 0.1)

samples = GGM_sampler.precision_sampler(precision, n_samples)

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "naive_mle")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_lasso")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_score_matching")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "clime")

# %%
n_spins = 500
n_samples = 5000

precision = GGM_sampler.precision_maker(n_spins, p = 0.1)

samples = GGM_sampler.precision_sampler(precision, n_samples)

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "naive_mle")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_score_matching")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_score_matching")
#
# File ~/Desktop/final/GGM_diagnostics.py:133, in complete_experiment(precision, n_samples, method, use_tol)
#     130     out = GGM_inference.graphical_lasso(samples_n)
#     132 elif method == "graphical_score_matching":
# --> 133     out = GGM_inference.graphical_score_matching(samples_n)
#     135 elif method == "clime":
#     136     out = GGM_inference.clime(samples_n)
#
# File ~/Desktop/final/GGM_inference.py:455, in graphical_score_matching(samples, lam, max_sweeps, inner_max, tol)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/final/GGM_inference.py:419, in _solve_sm_l1_row(empirical_covariance_np, i, lam, beta0, max_inner, tol)
# ...

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "clime")

# %%
GGM_diagnostics.complete_experiment(precision, n_samples, "graphical_lasso")
